# %% [markdown]
# # Imports
# import required libraries

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
import tensorflow as tf
import tensorflow.keras as keras
import tensorflow.keras.layers as layers
import tensorflow.keras.models as models
import tensorflow.keras.optimizers as optimizers
import tensorflow.keras.losses as losses
import tensorflow.keras.callbacks as callbacks
import numpy as np
# %matplotlib inline

# %%
tf.config.experimental.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# # Load Dataset
# import dataset path and label csv file. Read csv file using pandas library read_csv function.
# Visualize csv file data for first 35 readings.

# %%
DATASET_PATH = "../input/bee-vs-wasp/kaggle_bee_vs_wasp"

label_csv = os.path.join(DATASET_PATH, 'labels.csv')

# %%
label_df = pd.read_csv(label_csv)
label_df.head(35)
# Out:
#     id                               path  is_bee  is_wasp  is_otherinsect  \
# 0    1  bee1\10007154554_026417cfd0_n.jpg       1        0               0
# 1    2  bee1\10024864894_6dc54d4b34_n.jpg       1        0               0
# 2    3  bee1\10092043833_7306dfd1f0_n.jpg       1        0               0
# 3    4   bee1\1011948979_fc3637e779_w.jpg       1        0               0
# 4    5  bee1\10128235063_dca17db76c_n.jpg       1        0               0
# 5    6  bee1\10130729734_f68738333e_w.jpg       1        0               0
# 6    7  bee1\10166485783_9cd6706c72_n.jpg       1        0               0
# 7    8     bee1\10179824_84803290ac_m.jpg       1        0               0
# 8    9  bee1\10197482094_0176d1bacb_n.jpg       1        0               0
# 9   10  bee1\10242298546_aac12f5223_n.jpg       1        0               0
# 10  11  bee1\10290912366_20f0dbdb0e_m.jpg       1        0               0
# 11  12  bee1\10290912366_20f0dbdb0e_n.jpg       1        0               0
# 12  13  bee1\10319307805_02d44f6555_m.jpg       1        0               0
# 13  14  bee1\10319312035_07f21405de_n.jpg       1        0               0
# 14  15  bee1\10330536605_77cd1d5e37_n.jpg       1        0               0
# 15  16  bee1\10330536605_77cd1d5e37_w.jpg       1        0               0
# 16  17  bee1\10386457326_4cc07bac3b_n.jpg       1        0               0
# 17  18  bee1\10392500084_4b1ef7ffac_n.jpg       1        0               0
# 18  19  bee1\10392744445_277e994c9e_n.jpg       1        0               0
# 19  20  bee1\10392941093_f2f0abbd9d_n.jpg       1        0               0
# 20  21  bee1\10408546655_27654d0185_w.jpg       1        0               0
# 21  22  bee1\10408556086_0f661a361f_w.jpg       1        0               0
# 22  23   bee1\1044467943_594f56bd36_n.jpg       1        0               0
# 23  24  bee1\10457143913_149e654aaa_n.jpg       1        0               0
# 24  25  bee1\10626408266_c96b0fb945_n.jpg       1        0               0
# 25  26  bee1\10626649743_2f30cb33c3_n.jpg       1        0               0
# 26  27  bee1\10741832906_8cfa402d7b_n.jpg       1        0               0
# 27  28  bee1\10741839246_552d9b2a88_m.jpg       1        0               0
# 28  29  bee1\10767993123_11165835f0_n.jpg       1        0               0
# 29  30     bee1\10823833_f3cfe581b6_n.jpg       1        0               0
# 30  31     bee1\10823834_7f6ddb5bce_n.jpg       1        0               0
# 31  32    bee1\109174454_99ce7901c8_n.jpg       1        0               0
# 32  33   bee1\1096523362_266c05f368_m.jpg       1        0               0
# 33  34  bee1\11061289353_f22005ee19_n.jpg       1        0               0
# 34  35  bee1\11513862125_e99c104902_n.jpg       1        0               0
#
#     is_other  photo_quality  is_validation  is_final_validation label
# 0          0              1              0                    0   bee
# 1          0              1              0                    1   bee
# 2          0              1              1                    0   bee
# 3          0              1              0                    1   bee
# 4          0              1              0                    0   bee
# 5          0              1              0                    0   bee
# 6          0              1              0                    0   bee
# 7          0              1              0                    0   bee
# 8          0              1              0                    0   bee
# 9          0              1              0                    0   bee
# 10         0              1              1                    0   bee
# 11         0              1              0                    0   bee
# 12         0              1              0                    0   bee
# 13         0              1              0                    0   bee
# 14         0              1              1                    0   bee
# 15         0              1              0                    0   bee
# 16         0              1              0                    0   bee
# 17         0              1              0                    0   bee
# 18         0              1              0                    0   bee
# 19         0              1              0                    0   bee
# 20         0              1              0                    0   bee
# 21         0              1              0                    0   bee
# 22         0              1              0                    1   bee
# 23         0              1              1                    0   bee
# 24         0              1              0                    0   bee
# 25         0              1              0                    0   bee
# 26         0              1              0                    0   bee
# 27         0              1              0                    0   bee
# 28         0              1              0                    0   bee
# 29         0              1              0                    0   bee
# 30         0              1              1                    0   bee
# 31         0              1              1                    0   bee
# 32         0              1              0                    0   bee
# 33         0              1              0                    0   bee
# 34         0              1              0                    0   bee

# %% [markdown]
# # Understanding Dataset distribution
# create dataset distribution based on label.csv file. All the input images are distributed among training data, validation data and testing datasets. Images are distributed among 4 different classes namely bee, wasp, insect, other (non insect).

# %%
def dataset_distribution(row):
  if row['is_validation'] == 0 and row['is_final_validation'] == 0:
    return 'train'
  elif row['is_validation'] == 1:
    return 'validation'
  else:
    return 'test'
  
label_df['type'] = label_df.apply(dataset_distribution, axis = 1)
print('Number of images in each set:')
label_df['type'].value_counts()
# Out:
# Number of images in each set:
# train         7939
# test          1763
# validation    1719
# Name: type, dtype: int64

# %%
plt.figure(figsize = (7,7))
sb.countplot(x = 'label', hue='type', data= label_df)
plt.show()

# %%
label_df['path'] = label_df['path'].str.replace('\\', os.sep)
label_df['path'].head()
# Out:
# 0    bee1/10007154554_026417cfd0_n.jpg
# 1    bee1/10024864894_6dc54d4b34_n.jpg
# 2    bee1/10092043833_7306dfd1f0_n.jpg
# 3     bee1/1011948979_fc3637e779_w.jpg
# 4    bee1/10128235063_dca17db76c_n.jpg
# Name: path, dtype: object

# %% [markdown]
# # Setting up pipelines and data preprocessing
# setup training, validation and testing pipelines. Convert all images to image size of (224,224). Use ImageDataGenerator function of keras.preprocessing for preprocessing images to pipeline.

# %%
train_df = label_df[label_df['type'] == 'train']
validation_df = label_df[label_df['type'] == 'validation']
test_df = label_df[label_df['type'] == 'test']

# %%
image_size = (224,224)
BATCH_SIZE = 32
EPOCHS = 15
SEED = 42

# %%
datagen = keras.preprocessing.image.ImageDataGenerator(rescale=1./255.)

train_set = datagen.flow_from_dataframe(train_df, 
                                            directory=DATASET_PATH, 
                                            x_col="path", 
                                            y_col="label",
                                            target_size=image_size,
                                            seed = 42
                                       )


validation_set = datagen.flow_from_dataframe(validation_df, 
                                            directory=DATASET_PATH, 
                                            x_col="path", 
                                            y_col="label",
                                            target_size=image_size,
                                            seed = 42
                                           )

test_set = datagen.flow_from_dataframe(test_df, 
                                      directory=DATASET_PATH, 
                                      x_col="path", 
                                      y_col="label",
                                      target_size=image_size,
                                      seed = 42
                                      )
# Out:
# Found 7939 validated image filenames belonging to 4 classes.
# Found 1719 validated image filenames belonging to 4 classes.
# Found 1763 validated image filenames belonging to 4 classes.

# %%
number_of_classes = len(label_df['label'].unique())
print("number_of_classes : ",number_of_classes)
# Out:
# number_of_classes :  4

# %% [markdown]
# # Setup VGG19 model with imageNet weights
# Let's setup VGG19 CNN based model for object classification task. This model is pretrained with imageNet weights.
# ImageNet is a big dataset with 1.4M images and 1000 classes of web images. Let's check the performance of this model on bee classification task.

# %%
vgg19 = keras.applications.VGG19(include_top=False,weights="imagenet", input_shape=(224,224, 3),classifier_activation="softmax")

# %% [markdown]
# # adding last layer
# add last layer to vgg19 model with "softmax" activation function. Use Adam optimizer with learning rate set to 0.0001. Train the model for 50 epochs and verify the loss and accuracy after each epoch.

# %%
from tensorflow.keras.initializers import RandomNormal, Constant

model = models.Sequential([
    vgg19,
    layers.GlobalAveragePooling2D(),
    layers.Dropout(0.2),
    layers.Dense(number_of_classes,activation="softmax")
])

model.compile(optimizer=optimizers.Adam(learning_rate=0.0001),
              loss=losses.BinaryCrossentropy(),
              metrics=['accuracy']
             )

history = model.fit(train_set, 
          validation_data=validation_set, 
          batch_size=32,
          epochs=50,
         )
# Out:
# Epoch 1/50
# 249/249 [==============================] - 71s 279ms/step - loss: 0.4043 - accuracy: 0.6014 - val_loss: 0.2206 - val_accuracy: 0.7976
# Epoch 2/50
# 249/249 [==============================] - 69s 277ms/step - loss: 0.1917 - accuracy: 0.8457 - val_loss: 0.1686 - val_accuracy: 0.8598
# Epoch 3/50
# 249/249 [==============================] - 70s 279ms/step - loss: 0.1377 - accuracy: 0.8940 - val_loss: 0.1472 - val_accuracy: 0.8854
# Epoch 4/50
# 249/249 [==============================] - 69s 278ms/step - loss: 0.1054 - accuracy: 0.9201 - val_loss: 0.1351 - val_accuracy: 0.9092
# Epoch 5/50
# 249/249 [==============================] - 69s 277ms/step - loss: 0.0894 - accuracy: 0.9381 - val_loss: 0.1470 - val_accuracy: 0.9011
# Epoch 6/50
# 249/249 [==============================] - 69s 278ms/step - loss: 0.0713 - accuracy: 0.9470 - val_loss: 0.1629 - val_accuracy: 0.8877
# Epoch 7/50
# 249/249 [==============================] - 69s 278ms/step - loss: 0.0664 - accuracy: 0.9574 - val_loss: 0.2093 - val_accuracy: 0.8755
# Epoch 8/50
# 249/249 [==============================] - 69s 277ms/step - loss: 0.0583 - accuracy: 0.9590 - val_loss: 0.1587 - val_accuracy: 0.8854
# Epoch 9/50
# 249/249 [==============================] - 69s 277ms/step - loss: 0.0414 - accuracy: 0.9685 - val_loss: 0.1292 - val_accuracy: 0.9186
# Epoch 10/50
# 249/249 [==============================] - 69s 278ms/step - loss: 0.0336 - accuracy: 0.9764 - val_loss: 0.1521 - val_accuracy: 0.9098
# Epoch 11/50
# 249/249 [==============================] - 70s 280ms/step - loss: 0.0460 - accuracy: 0.9697 - val_loss: 0.1339 - val_accuracy: 0.9139
# Epoch 12/50
# 249/249 [==============================] - 69s 278ms/step - loss: 0.0278 - accuracy: 0.9826 - val_loss: 0.1580 - val_accuracy: 0.9092
# Epoch 13/50
# 249/249 [==============================] - 69s 277ms/step - loss: 0.0308 - accuracy: 0.9799 - val_loss: 0.1387 - val_accuracy: 0.9133
# Epoch 14/50
# 249/249 [==============================] - 69s 277ms/step - loss: 0.0264 - accuracy: 0.9813 - val_loss: 0.2046 - val_accuracy: 0.8930
# Epoch 15/50
# 249/249 [==============================] - 69s 278ms/step - loss: 0.0138 - accuracy: 0.9908 - val_loss: 0.1906 - val_accuracy: 0.9174
# Epoch 16/50
# 249/249 [==============================] - 69s 278ms/step - loss: 0.0223 - accuracy: 0.9858 - val_loss: 0.1677 - val_accuracy: 0.9168
# Epoch 17/50
# 249/249 [==============================] - 69s 276ms/step - loss: 0.0168 - accuracy: 0.9898 - val_loss: 0.1934 - val_accuracy: 0.9069
# Epoch 18/50
# 249/249 [==============================] - 69s 277ms/step - loss: 0.0141 - accuracy: 0.9907 - val_loss: 0.1782 - val_accuracy: 0.9191
# Epoch 19/50
# 249/249 [==============================] - 70s 279ms/step - loss: 0.0156 - accuracy: 0.9911 - val_loss: 0.2757 - val_accuracy: 0.9098
# Epoch 20/50
# 249/249 [==============================] - 69s 276ms/step - loss: 0.0167 - accuracy: 0.9891 - val_loss: 0.2238 - val_accuracy: 0.9145
# Epoch 21/50
# 249/249 [==============================] - 69s 278ms/step - loss: 0.0167 - accuracy: 0.9905 - val_loss: 0.2091 - val_accuracy: 0.9127
# Epoch 22/50
# 249/249 [==============================] - 69s 277ms/step - loss: 0.0180 - accuracy: 0.9885 - val_loss: 0.2511 - val_accuracy: 0.9017
# Epoch 23/50
# 249/249 [==============================] - 69s 277ms/step - loss: 0.0272 - accuracy: 0.9810 - val_loss: 0.2211 - val_accuracy: 0.9186
# Epoch 24/50
# 249/249 [==============================] - 69s 277ms/step - loss: 0.0121 - accuracy: 0.9916 - val_loss: 0.1839 - val_accuracy: 0.9180
# Epoch 25/50
# 249/249 [==============================] - 69s 278ms/step - loss: 0.0105 - accuracy: 0.9934 - val_loss: 0.2209 - val_accuracy: 0.9092
# Epoch 26/50
# 249/249 [==============================] - 69s 277ms/step - loss: 0.0071 - accuracy: 0.9953 - val_loss: 0.2310 - val_accuracy: 0.9116
# Epoch 27/50
# 249/249 [==============================] - 69s 277ms/step - loss: 0.0043 - accuracy: 0.9975 - val_loss: 0.1696 - val_accuracy: 0.9145
# Epoch 28/50
# 249/249 [==============================] - 69s 277ms/step - loss: 0.0157 - accuracy: 0.9899 - val_loss: 0.2535 - val_accuracy: 0.8953
# Epoch 29/50
# 249/249 [==============================] - 69s 278ms/step - loss: 0.0180 - accuracy: 0.9906 - val_loss: 0.2199 - val_accuracy: 0.9156
# Epoch 30/50
# 249/249 [==============================] - 69s 278ms/step - loss: 0.0055 - accuracy: 0.9965 - val_loss: 0.2913 - val_accuracy: 0.8802
# Epoch 31/50
# 249/249 [==============================] - 69s 278ms/step - loss: 0.0129 - accuracy: 0.9933 - val_loss: 0.2306 - val_accuracy: 0.9145
# Epoch 32/50
# 249/249 [==============================] - 69s 277ms/step - loss: 0.0067 - accuracy: 0.9972 - val_loss: 0.1933 - val_accuracy: 0.8773
# Epoch 33/50
# 249/249 [==============================] - 69s 277ms/step - loss: 0.0247 - accuracy: 0.9828 - val_loss: 0.2564 - val_accuracy: 0.9145
# Epoch 34/50
# 249/249 [==============================] - 69s 277ms/step - loss: 0.0072 - accuracy: 0.9955 - val_loss: 0.2190 - val_accuracy: 0.9156
# Epoch 35/50
# 249/249 [==============================] - 69s 278ms/step - loss: 0.0070 - accuracy: 0.9963 - val_loss: 0.3082 - val_accuracy: 0.9075
# Epoch 36/50
# 249/249 [==============================] - 69s 278ms/step - loss: 0.0017 - accuracy: 0.9991 - val_loss: 0.2310 - val_accuracy: 0.8889
# Epoch 37/50
# 249/249 [==============================] - 69s 278ms/step - loss: 0.0181 - accuracy: 0.9890 - val_loss: 0.1872 - val_accuracy: 0.9046
# Epoch 38/50
# 249/249 [==============================] - 69s 276ms/step - loss: 0.0140 - accuracy: 0.9904 - val_loss: 0.2726 - val_accuracy: 0.9203
# Epoch 39/50
# 249/249 [==============================] - 69s 276ms/step - loss: 0.0037 - accuracy: 0.9974 - val_loss: 0.2405 - val_accuracy: 0.8965
# Epoch 40/50
# 249/249 [==============================] - 69s 276ms/step - loss: 0.0124 - accuracy: 0.9930 - val_loss: 0.2465 - val_accuracy: 0.9191
# Epoch 41/50
# 249/249 [==============================] - 69s 276ms/step - loss: 0.0048 - accuracy: 0.9971 - val_loss: 0.2161 - val_accuracy: 0.9046
# Epoch 42/50
# 249/249 [==============================] - 69s 276ms/step - loss: 0.0086 - accuracy: 0.9945 - val_loss: 0.1972 - val_accuracy: 0.8965
# Epoch 43/50
# 249/249 [==============================] - 69s 276ms/step - loss: 0.0108 - accuracy: 0.9953 - val_loss: 0.3039 - val_accuracy: 0.9023
# Epoch 44/50
# 249/249 [==============================] - 69s 276ms/step - loss: 0.0145 - accuracy: 0.9923 - val_loss: 0.2643 - val_accuracy: 0.9197
# Epoch 45/50
# 249/249 [==============================] - 69s 276ms/step - loss: 0.0053 - accuracy: 0.9964 - val_loss: 0.2429 - val_accuracy: 0.9005
# Epoch 46/50
# 249/249 [==============================] - 70s 279ms/step - loss: 0.0048 - accuracy: 0.9977 - val_loss: 0.2127 - val_accuracy: 0.9238
# Epoch 47/50
# 249/249 [==============================] - 69s 276ms/step - loss: 0.0031 - accuracy: 0.9986 - val_loss: 0.1896 - val_accuracy: 0.8930
# Epoch 48/50
# 249/249 [==============================] - 69s 277ms/step - loss: 0.0135 - accuracy: 0.9918 - val_loss: 0.2204 - val_accuracy: 0.9209
# Epoch 49/50
# 249/249 [==============================] - 69s 276ms/step - loss: 0.0052 - accuracy: 0.9974 - val_loss: 0.2798 - val_accuracy: 0.9273
# Epoch 50/50
# 249/249 [==============================] - 69s 277ms/step - loss: 0.0030 - accuracy: 0.9988 - val_loss: 0.2754 - val_accuracy: 0.8965

# %% [markdown]
# # Plot loss vs Accuracy
# plot trainig loss vs accuracy curve. Compare this curves with validation loss and validation accuracy curves.

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(14,5))
plt.subplot(1, 2, 1)
plt.plot(acc, label='train acc')
plt.plot(val_acc, label='valid acc')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(loss, label='train loss')
plt.plot(val_loss, label='valid loss')
plt.legend()

plt.show()

# %% [markdown]
# # Evaluating model on test set
# Evaluate the model performance on test set. Check the testing accuracy.

# %%
test_loss, test_acc = model.evaluate(test_set, verbose=2)
print("Test accuracy:", test_acc)
# Out:
# 56/56 - 8s - loss: 0.2631 - accuracy: 0.9030
# Test accuracy: 0.9030062556266785

# %% [markdown]
# # Visualize classification on sample test images
#
# Define function load image to load images and process it to fit the model requirement. Pass sample images to this function and get the output for model.predict_classes function.
#
# model.predict_classes function will give us the most likely class of the image.

# %%
from keras.preprocessing import image
def load_image(img_path, show=False):

    img = image.load_img(img_path, target_size=(224,224))
    imgplot = plt.imshow(img)
    img_tensor = image.img_to_array(img)                    # (height, width, channels)
    img_tensor = np.expand_dims(img_tensor, axis=0)         # (1, height, width, channels), add a dimension because the model expects this shape: (batch_size, height, width, channels)
    img_tensor /= 255.                                      # imshow expects values in the range [0, 1]

    if show:
        plt.imshow(img_tensor[0])                           
        plt.axis('off')
        plt.show()

    return img_tensor

# %%
# image path
img_path = '../input/bee-vs-wasp/kaggle_bee_vs_wasp/wasp1/1032128732_50dade4f6f_n.jpg'

# load a single image
new_image = load_image(img_path)

# check prediction
pred = model.predict_classes(new_image)
print(pred[0])
    
    
if pred[0] == 0:
  print("Bee")
elif pred[0] == 1:
  print("insect")
elif pred[0] == 2:
  print("other non insect")
elif pred[0] == 3:
  print("Wasp")
# Out:
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# 3
# Wasp

# %%
# image path
img_path = '../input/bee-vs-wasp/kaggle_bee_vs_wasp/bee1/10024864894_6dc54d4b34_n.jpg'    # dog
#img_path = '/media/data/dogscats/test1/19.jpg'      # cat

# load a single image
new_image = load_image(img_path)

# check prediction
pred = model.predict_classes(new_image)
print(pred[0])
    
    
if pred[0] == 0:
  print("Bee")
elif pred[0] == 1:
  print("insect")
elif pred[0] == 2:
  print("other non insect")
elif pred[0] == 3:
  print("Wasp")
# Out:
# 0
# Bee
